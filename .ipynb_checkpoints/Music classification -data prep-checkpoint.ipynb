# %% [markdown]
# # Music Classification - Webapp Frame & Data Prep

# %% [markdown]
# So far, our group has retrieved dataset from the web. The dataset would be used as training/testing dataset in our future machine learning model. And, our group has worked on the framework building of our webapp.

# %% [markdown]
# ## Data Cleaning

# %%
import pandas as pd
df = pd.read_csv("tcc_ceds_music.csv")

# %%
df.head()
# Out:
#    Unnamed: 0           artist_name            track_name  release_date genre  \
# 0           0                mukesh  mohabbat bhi jhoothi          1950   pop
# 1           4         frankie laine             i believe          1950   pop
# 2           6           johnnie ray                   cry          1950   pop
# 3          10           pérez prado              patricia          1950   pop
# 4          12  giorgos papadopoulos    apopse eida oneiro          1950   pop
#
#                                               lyrics  len    dating  violence  \
# 0  hold time feel break feel untrue convince spea...   95  0.000598  0.063746
# 1  believe drop rain fall grow believe darkest ni...   51  0.035537  0.096777
# 2  sweetheart send letter goodbye secret feel bet...   24  0.002770  0.002770
# 3  kiss lips want stroll charm mambo chacha merin...   54  0.048249  0.001548
# 4  till darling till matter know till dream live ...   48  0.001350  0.001350
#
# ...

# %%
# Out:
#   File "<tokenize>", line 14
#     <h1>Submit</h1>
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
df = df.drop(["Unnamed: 0", "release_date"], axis =1)
df.head()
# Out:
#             artist_name            track_name genre  \
# 0                mukesh  mohabbat bhi jhoothi   pop
# 1         frankie laine             i believe   pop
# 2           johnnie ray                   cry   pop
# 3           pérez prado              patricia   pop
# 4  giorgos papadopoulos    apopse eida oneiro   pop
#
#                                               lyrics  len    dating  violence  \
# 0  hold time feel break feel untrue convince spea...   95  0.000598  0.063746
# 1  believe drop rain fall grow believe darkest ni...   51  0.035537  0.096777
# 2  sweetheart send letter goodbye secret feel bet...   24  0.002770  0.002770
# 3  kiss lips want stroll charm mambo chacha merin...   54  0.048249  0.001548
# 4  till darling till matter know till dream live ...   48  0.001350  0.001350
#
#    world/life  night/time  shake the audience  ...   sadness  feelings  \
# 0    0.000598    0.000598            0.000598  ...  0.380299  0.117175
# ...

# %% [markdown]
# ## Webapp Frame

# %% [markdown]
# For webapp building, we first edit the `app.py` file. There are a few html files implemented in this file, which will be introduced later.

# %%
from flask import Flask, g, render_template, request
import sqlite3

app = Flask(__name__)

@app.route("/")
def main():
    return render_template("base.html")
def hello():
    return render_template("hello.html")

@app.route("/submit/", methods = ["POST", "GET"])
def submit():
    if request.method == "POST":
        return render_template("submit.html")
    else:
        try:
            return render_template("submit.html")
        except:
            return render_template("submit.html")

# %% [markdown]
# We have also built three html files, serving for app.py to build the webpage.
# > ### base.html

# %%
<!doctype html>
<link rel="stylesheet" href="{{ url_for('static', filename='style.css') }}">
<title>Music Classifier</title>
<nav>
  <h1>Input Song Lyrics to Get Song's Sentiment</h1>
  <ul>
    <li><a href="{{ url_for('submit') }}">Input song lyrics</a></li>

  </ul>
</nav>
<section class="content">
    <header>
      {% block header %}{% endblock %}
    </header>
    {% block content %}{% endblock %}
  </section>

# %% [markdown]
# > ### submit.html

# %%
{% extends 'base.html' %}

{% block header %}
  <h1>{% block title %}Submit{% endblock %}</h1>
{% endblock %}

{% block content %}
  <form method="post">
    <label for="lyrics">Your song lyrics:</label>
    <br>
    <input name="lyrics" id="lyrics"> 
    <br>
    <input type="submit" value="Submit lyrics">
  </form>

  <!--
  {% if thanks %}
    Thanks for submitting a file!
  {% endif %}

  {% if digit %}
    <br>
    Thanks for the image!  It looks like a {{digit}}.
    <br>
    <img src="{{ image }}", alt="an 8x8 visualization of the supplied digit."/>
  {% endif %}

  {% if error %}
    <br>
    Oh no, we couldn't use that file!  Please upload an 8x8 numpy array as a text file.
  {% endif %}
{% endblock %}
  -->

# %% [markdown]
# > ### hello.html

# %%
{% extends 'base.html' %}

{% block header %}
  <h1>{% block title %}Main page{% endblock %}</h1>
{% endblock %}

{% block content %}
{% if name %}
  Hello, {{name}}!
{% else %}
  Hello there! Input lyrics and we will analyze the sentiments for you.
{% endif %}
{% endblock %}
